# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
sold = pd.read_csv("sold_final.csv", low_memory=False)
sold.shape
# Out:
# (412434, 81)

# %%
len(sold["CountyOrParish"].unique()), len(sold["MLSAreaMajor"].unique())
# Out:
# (63, 1089)

# %%
len(sold["ListOfficeName"].unique()), len(sold["BuyerOfficeName"].unique())
# Out:
# (18661, 21243)

# %%
key_metrics = ["PriceRatio", "PricePerSqft", "DaysOnMarket", "YearMonth",
               "ListContractDays", "ContractCloseDays"]

# %%
sold.groupby("PropertySubType")[key_metrics].describe()
# Out:
#                       PriceRatio                                               \
#                            count      mean        std           min       25%
# PropertySubType
# BoatSlip                    45.0  0.949640   0.068600  6.489676e-01  0.928571
# Cabin                      470.0  0.937602   0.100678  4.800000e-01  0.901203
# CoOwnership                 17.0  0.964626   0.041166  8.750000e-01  0.941176
# Condominium              68269.0  1.171701  13.176317  5.355098e-04  0.974747
# DeededParking                4.0  1.010123   0.042583  9.600000e-01  0.990000
# Duplex                    2250.0  0.990856   0.084210  1.000000e-01  0.960000
# Farm                        14.0  0.979618   0.098171  8.189263e-01  0.919082
# Loft                        28.0  0.994644   0.048402  8.761905e-01  0.975254
# ManufacturedHome            40.0  0.972673   0.051433  8.466667e-01  0.936113
# ManufacturedOnLand        5335.0  0.973458   0.145662  9.803922e-04  0.951952
# ...
